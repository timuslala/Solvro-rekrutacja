# %%
import pandas as pd
from helpers import perform_weighted_one_hot_encoding

df = pd.read_pickle("../data/cocktail_dataset_v1.pkl")

# %%
df = df.join(pd.get_dummies(df["glass"], prefix="glass"))

# %%
perform_weighted_one_hot_encoding(df)
# Out:
# C:\Users\timus\kod\Solvro-rekrutacja\helpers\ingredients.py:199: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[0.2  0.33 0.2 ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[
# C:\Users\timus\kod\Solvro-rekrutacja\helpers\ingredients.py:199: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[0.0625 0.1875 0.25   0.25   0.25   0.1875 0.1875 0.1875 0.1875]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[
# C:\Users\timus\kod\Solvro-rekrutacja\helpers\ingredients.py:199: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[0.125   0.04166]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[
# ...

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.expand_frame_repr", False)
df_preprocessed = pd.concat([df.iloc[:, 1], df.iloc[:, -32:]], axis=1)

# %%
df_preprocessed
# Out:
#                       name  glass_Brandy snifter  glass_Champagne flute  glass_Cocktail glass  glass_Collins glass  glass_Copper Mug  glass_Highball glass  glass_Old-fashioned glass  glass_Pousse cafe glass  glass_Whiskey Glass  glass_Whiskey sour glass  glass_White wine glass  ingredient_water  ingredient_rum  ingredient_fortified_wine  ingredient_syrup  ingredient_spirit  ingredient_bitter  ingredient_vodka  ingredient_liqueur  ingredient_gin  ingredient_whisky  ingredient_soft_drink  ingredient_wine  ingredient_fruit  ingredient_juice  ingredient_egg  ingredient_cream  ingredient_tea  ingredient_salt  ingredient_flower  ingredient_spice  ingredient_sauce
# ...

# %%
df_preprocessed.to_pickle("../data/cocktail_dataset_preprocessed.pkl")
